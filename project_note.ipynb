# %%
import pandas as pd
# Read data from file
df = pd.read_csv('adult.data.csv')
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
# How many of each race are represented in this dataset? This should be a Pandas series with race names as the index labels.
race_count = df['race'].value_counts()
race_count
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
# What is the average age of men?
average_age_men = round(float(df[df['sex']=='Male']['age'].mean()),1)
average_age_men
# Out:
# 39.4

# %%
# What is the percentage of people who have a Bachelor's degree?
percentage_bachelors = round(int(df[df['education']=='Bachelors']['education'].count())*100.0/float(df['education'].count()),1)
percentage_bachelors
# Out:
# 16.4

# %%
# What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
# What percentage of people without advanced education make more than 50K?
# with and without `Bachelors`, `Masters`, or `Doctorate`
higher_education =float(df[(
        ((df['education']=='Bachelors')|
        (df['education']=='Masters') |
        (df['education']=='Doctorate')))]['education'].count())
higher_education
# Out:
# 25070.0

# %%
lower_education =float(df[(
        ~((df['education']=='Bachelors')|
        (df['education']=='Masters') |
        (df['education']=='Doctorate')))]['education'].count())
lower_education

# %%
# percentage with salary >50K
higher_education_rich = round(int(
    df[(
        ((df['education']=='Bachelors')|
        (df['education']=='Masters') |
        (df['education']=='Doctorate')) & (df['salary']=='>50K')
    )]
    ['education'].count())*100.0/float(df[(
        ((df['education']=='Bachelors')|
        (df['education']=='Masters') |
        (df['education']=='Doctorate')))]['education'].count()),1)
higher_education_rich

# %%
lower_education_rich = round(int(
    df[(
        ~((df['education']=='Bachelors')|
        (df['education']=='Masters') |
        (df['education']=='Doctorate')) & (df['salary']=='>50K')
    )]
    ['education'].count())*100.0/float(df[(
        ~((df['education']=='Bachelors')|
        (df['education']=='Masters') |
        (df['education']=='Doctorate')))]['education'].count()),1)
lower_education

# %%
# What is the minimum number of hours a person works per week (hours-per-week feature)?
min_work_hours = min(df['hours-per-week'])
min_work_hours
# Out:
# 1

# %%
# What percentage of the people who work the minimum number of hours per week have a salary of >50K?
num_min_workers = df[df['hours-per-week']==min_work_hours]
num_min_workers
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 189     58         State-gov  109567     Doctorate             16
# 1036    66      Self-emp-inc  150726           9th              5
# 1262    69                 ?  195779     Assoc-voc             11
# 5590    78                 ?  363134       HS-grad              9
# 5632    45                 ?  189564       Masters             14
# 5766    62                 ?   97231  Some-college             10
# 5808    76                 ?  211574          10th              6
# 8447    67                 ?  244122     Assoc-voc             11
# 9147    75                 ?  260543          10th              6
# 11451   27           Private  147951       HS-grad              9
# 19337   72                 ?   76860       HS-grad              9
# 19750   23           Private   72887       HS-grad              9
# 20072   65                 ?   76043       HS-grad              9
# ...

# %%
rich_percentage = int(num_min_workers[num_min_workers['salary']==">50K"]['salary'].count()*100.0/num_min_workers['salary'].count())
rich_percentage
# Out:
# 10

# %%
# What country has the highest percentage of people that earn >50K?
highest_earning_country =(df[df['salary']==">50K"]['native-country'].value_counts())
highest_earning_country.index[0]
# Out:
# 'United-States'

# %%
highest_earning_country_percentage = round(float(highest_earning_country[0]*100.0/highest_earning_country.sum()),1)
highest_earning_country_percentage
# Out:
# C:\Users\ahmed\AppData\Local\Temp\ipykernel_12364\4281558204.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   highest_earning_country_percentage = round(float(highest_earning_country[0]*100.0/highest_earning_country.sum()),1)
# 91.5

# %%
# Identify the most popular occupation for those who earn >50K in India.
top_IN_occupation = df[(df['native-country']=='India')&( df['salary']==">50K")]['occupation'].value_counts()
top_IN_occupation.index[0]
# Out:
# 'Prof-specialty'
